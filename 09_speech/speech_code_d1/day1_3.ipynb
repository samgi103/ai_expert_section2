# %%
import torch
import torchaudio
import matplotlib.pyplot as plt
import numpy as np
from scipy.io.wavfile import read, write
from scipy.signal import lfilter
from google.colab import files

from data.featurizer import FilterBankFeaturizer
from data.tokenizer import GraphemeTokenizer

# Lowpass Filtering

# Define the FIR filter
fir_filter = np.array([
    # your coefficients here...
])

# Upload the WAV file
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])
  ))

# The filename will be the key of the uploaded dictionary
filename = list(uploaded.keys())[0]

# Read the WAV file
sample_rate, data = read(filename)

# Perform FIR filtering
filtered_data = np.asarray(filtered_data, dtype=np.int16)

# Write the filtered data to a new WAV file
output_filename = 'output.wav'
write(output_filename, sample_rate, filtered_data)

# Save Filtered waveform
wave = filename # sample file path
filtered = 'output.wav' # filtered file path
sr = 16000

mel_transform = FilterBankFeaturizer(sr, 0.025, 0.01, use_aug=False)

feature = mel_transform(wave)
feature2 = mel_transform(filtered)
fig, ax = plt.subplots(2)
ax[0].imshow(feature.t())
ax[0].invert_yaxis()
ax[1].imshow(feature2.t())
ax[1].invert_yaxis()
fig.show()

# Download the filtered WAV file
files.download(output_filename)
